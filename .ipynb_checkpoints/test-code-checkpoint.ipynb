# %%
from dotenv import load_dotenv
import os
import pandas as pd
import coinmarketcapapi
from coinmarketcapapi import CoinMarketCapAPI
import matplotlib.pyplot as plt
import hvplot.pandas
import plotly.express as px
import panel as pn
pn.extension('plotly')

# %%
load_dotenv()

# %%
name = input("Hello, What is your name? ") 
print("Hi!", name) 
print("Welcome to our Crypto data set.") 
print("Amongst our research and investing in both the stock market and crypto markets, \
we seek to find a patern of liquidity flow within larger crypto wallets and crypto exchanges during \
times of sudden price drops in the crypto markets.") 
answer = input("Are you familar with crypto currency either through personal means or media?")
if answer == "Yes" or "yes": 
    input("Are you currently or have you invested in crypto currency?") 
elif answer == "No" or "no": 
    print("Welcome", name + " We hope the data we chart can help both current investors and anyone interested in either \
learning more about crypto exchange flow or investing themeselves. Enjoy our wallet and exchange flow data" )
# Out:
# Hello, What is your name? Stephen
# Hi! Stephen
# Welcome to our Crypto data set.
# Amongst our research and investing in both the stock market and crypto markets, we seek to find a patern of liquidity flow within larger crypto wallets and crypto exchanges during times of sudden price drops in the crypto markets.
# Are you familar with crypto currency either through personal means or media?Yes
# Are you currently or have you invested in crypto currency?Yes

# %%
cmc_api = os.getenv('CMC_API_KEY')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-28b518b2c247> in <module>
# ----> 1 cmc_api = os.getenv('CMC_API_KEY')
#
# NameError: name 'os' is not defined

# %%
cmc = CoinMarketCapAPI(cmc_api)

# %%
global_quote = cmc.globalmetrics_quotes_latest()
global_quote
# Out:
# RESPONSE: 211ms OK: {'active_cryptocurrencies': 5534, 'total_cryptocurrencies': 10296, 'active_market_pairs': 42434, 'active_exchanges': 383, 'total_exchanges': 1386, 'eth_dominance': 18.749342937377, 'btc_dominance': 41.503252321599, 'defi_volume_24h': 8120319976.313748, 'defi_volume_24h_reported': 8120319976.313748, 'defi_market_cap': 83076394006.67668, 'defi_24h_percentage_change': -24.525451556924, 'stablecoin_volume_24h': 81586418583.06337, 'stablecoin_volume_24h_reported': 81586418583.06337, 'stablecoin_market_cap': 108597963322.28806, 'stablecoin_24h_percentage_change': -22.501133138245, 'derivatives_volume_24h': 151995970479.65253, 'derivatives_volume_24h_reported': 151995970479.65253, 'derivatives_24h_percentage_change': -19.537368120598, 'quote': {'USD': {'total_market_cap': 1629033180066.191, 'total_volume_24h': 102070780880.94, 'total_volume_24h_reported': 102070780880.94, 'altcoin_volume_24h': 67533134156.145966, 'altcoin_volume_24h_reported': 67533134156.145966, 'altcoin_market_cap': 952931428940.7488, 'last_updated': '2021-06-05T18:40:17.999Z'}}, 'last_updated': '2021-06-05T18:40:17.999Z'}

# %%
global_df = pd.DataFrame(global_quote.data)
global_df.head()
# Out:
#      active_cryptocurrencies  total_cryptocurrencies  active_market_pairs  \
# USD                     5534                   10296                42434
#
#      active_exchanges  total_exchanges  eth_dominance  btc_dominance  \
# USD               383             1386      18.749343      41.503252
#
#      defi_volume_24h  defi_volume_24h_reported  defi_market_cap  \
# USD     8.120320e+09              8.120320e+09     8.307639e+10
#
#      defi_24h_percentage_change  stablecoin_volume_24h  \
# USD                  -24.525452           8.158642e+10
#
#      stablecoin_volume_24h_reported  stablecoin_market_cap  \
# USD                    8.158642e+10           1.085980e+11
#
#      stablecoin_24h_percentage_change  derivatives_volume_24h  \
# USD                        -22.501133            1.519960e+11
#
#      derivatives_volume_24h_reported  derivatives_24h_percentage_change  \
# USD                     1.519960e+11                         -19.537368
#
#                                                  quote  \
# USD  {'total_market_cap': 1629033180066.191, 'total...
#
#                  last_updated
# USD  2021-06-05T18:40:17.999Z

# %%
data_id_map = cmc.cryptocurrency_map()
data_idmap = pd.DataFrame(data_id_map.data)
data_idmap_df = data_idmap.set_index('rank')
idmap_data = data_idmap_df.sort_index(ascending=True)
idmap_data
# Out:
#          first_historical_data     id  is_active      last_historical_data  \
# rank
# 1     2013-04-28T18:47:21.000Z      1          1  2021-06-05T18:39:03.000Z
# 2     2015-08-07T14:49:30.000Z   1027          1  2021-06-05T18:39:03.000Z
# 3     2015-02-25T13:34:26.000Z    825          1  2021-06-05T18:39:11.000Z
# 4     2017-07-25T04:30:05.000Z   1839          1  2021-06-05T18:39:10.000Z
# 5     2017-10-01T20:34:25.000Z   2010          1  2021-06-05T18:39:16.000Z
# 6     2013-12-15T14:42:34.000Z     74          1  2021-06-05T18:39:03.000Z
# 7     2013-08-04T18:51:05.000Z     52          1  2021-06-05T18:39:03.000Z
# 8     2018-10-08T18:49:28.000Z   3408          1  2021-06-05T18:39:04.000Z
# 9     2020-08-20T03:29:22.000Z   6636          1  2021-06-05T18:39:07.000Z
# 10    2020-09-17T01:14:14.000Z   7083          1  2021-06-05T18:39:12.000Z
# 11    2021-05-10T11:03:07.000Z   8916          1  2021-06-05T18:38:07.000Z
# 12    2017-07-23T16:29:27.000Z   1831          1  2021-06-05T18:39:07.000Z
# 13    2017-09-20T20:54:59.000Z   1975          1  2021-06-05T18:39:13.000Z
# 14    2013-04-28T18:47:22.000Z      2          1  2021-06-05T18:39:02.000Z
# 15    2020-04-10T04:59:18.000Z   5426          1  2021-06-05T18:39:05.000Z
# 16    2019-04-28T20:04:10.000Z   3890          1  2021-06-05T18:39:13.000Z
# 17    2019-09-20T08:34:14.000Z   4687          1  2021-06-05T18:39:06.000Z
# 18    2018-01-17T17:34:26.000Z   2416          1  2021-06-05T18:39:06.000Z
# 19    2014-08-05T05:44:19.000Z    512          1  2021-06-05T18:39:06.000Z
# 20    2018-08-03T17:04:23.000Z   3077          1  2021-06-05T18:39:02.000Z
# 21    2016-07-24T13:44:30.000Z   1321          1  2021-06-05T18:39:05.000Z
# 22    2017-12-13T20:40:00.000Z   2280          1  2021-06-05T18:39:04.000Z
# 23    2019-01-30T18:19:09.000Z   3717          1  2021-06-05T18:39:06.000Z
# 24    2017-07-01T19:14:14.000Z   1765          1  2021-06-05T18:39:07.000Z
# 25    2017-09-13T01:15:22.000Z   1958          1  2021-06-05T18:39:14.000Z
# 5530  2021-06-02T18:24:02.000Z  10240          1  2021-06-05T18:39:02.000Z
#
#                        name  \
# rank
# 1                   Bitcoin
# 2                  Ethereum
# 3                    Tether
# 4              Binance Coin
# 5                   Cardano
# 6                  Dogecoin
# 7                       XRP
# 8                  USD Coin
# 9                  Polkadot
# 10                  Uniswap
# 11        Internet Computer
# 12             Bitcoin Cash
# 13                Chainlink
# 14                 Litecoin
# 15                   Solana
# 16                  Polygon
# 17              Binance USD
# 18                    THETA
# 19                  Stellar
# 20                  VeChain
# 21         Ethereum Classic
# 22                 Filecoin
# 23          Wrapped Bitcoin
# 24                      EOS
# 25                     TRON
# 26                   Monero
# 27                      Dai
# 28                     Aave
# 29                      Neo
# 30                    Maker
# ...                     ...
# 5501             Beer Token
# 5502         Aurora Finance
# 5503        Elongate Deluxe
# 5504              Lady Luck
# 5505               Snowball
# 5506              Avalaunch
# 5507                VELOREX
# 5508                Evai.io
# 5509               xxxNifty
# 5510            Rafflection
# 5511              Wild Ride
# 5512                 AzeusX
# 5513              POOROCKET
# 5514                   CHAD
# 5515             Grill.Farm
# 5516              GingerCat
# 5517            DINGO TOKEN
# 5518             Wise Token
# 5519          Panda Finance
# 5520         Rocket Moon GO
# 5521              Seraphium
# 5522               PolyDoge
# 5523  Gold Secured Currency
# 5524            Elk Finance
# 5525                PETBloc
# 5526   Museum of Crypto Art
# 5527               Polywolf
# 5528                miMatic
# 5529             SpiritSwap
# 5530         Wrapped Fantom
#
#                                                platform  \
# rank
# 1                                                  None
# 2                                                  None
# 3     {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
# 4                                                  None
# 5                                                  None
# 6                                                  None
# 7                                                  None
# 8     {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
# 9                                                  None
# 10    {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
# 11                                                 None
# 12                                                 None
# 13    {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
# 14                                                 None
# 15                                                 None
# 16    {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
# 17    {'id': 1839, 'name': 'Binance Chain', 'symbol'...
# 18                                                 None
# 19                                                 None
# 20                                                 None
# 21                                                 None
# 22                                                 None
# 23    {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
# 24                                                 None
# 25                                                 None
# 26                                                 None
# 27    {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
# 28    {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
# 29                                                 None
# 30    {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
# ...                                                 ...
# 5501  {'id': 1839, 'name': 'Binance Smart Chain', 's...
# 5502  {'id': 1839, 'name': 'Binance Smart Chain', 's...
# 5503  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
# 5504  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
# 5505  {'id': 5805, 'name': 'Avalanche Contract Chain...
# 5506  {'id': 5805, 'name': 'Avalanche Contract Chain...
# 5507  {'id': 1839, 'name': 'Binance Smart Chain', 's...
# 5508  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
# 5509  {'id': 1839, 'name': 'Binance Smart Chain', 's...
# 5510  {'id': 1839, 'name': 'Binance Smart Chain', 's...
# 5511  {'id': 1839, 'name': 'Binance Smart Chain', 's...
# 5512  {'id': 1958, 'name': 'Tron', 'symbol': 'TRX', ...
# 5513  {'id': 1839, 'name': 'Binance Smart Chain', 's...
# 5514  {'id': 1839, 'name': 'Binance Smart Chain', 's...
# 5515  {'id': 1839, 'name': 'Binance Smart Chain', 's...
# 5516  {'id': 1839, 'name': 'Binance Smart Chain', 's...
# 5517  {'id': 1839, 'name': 'Binance Smart Chain', 's...
# 5518  {'id': 1839, 'name': 'Binance Smart Chain', 's...
# 5519  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
# 5520  {'id': 1839, 'name': 'Binance Smart Chain', 's...
# 5521  {'id': 1839, 'name': 'Binance Smart Chain', 's...
# 5522  {'id': 3890, 'name': 'Polygon', 'symbol': 'MAT...
# 5523                                               None
# 5524  {'id': 3890, 'name': 'Polygon', 'symbol': 'MAT...
# 5525  {'id': 1839, 'name': 'Binance Smart Chain', 's...
# 5526  {'id': 3890, 'name': 'Polygon', 'symbol': 'MAT...
# 5527  {'id': 3890, 'name': 'Polygon', 'symbol': 'MAT...
# 5528  {'id': 3890, 'name': 'Polygon', 'symbol': 'MAT...
# 5529  {'id': 3513, 'name': 'Fantom', 'symbol': 'FTM'...
# 5530  {'id': 3513, 'name': 'Fantom', 'symbol': 'FTM'...
#
#                        slug     symbol
# rank
# 1                   bitcoin        BTC
# 2                  ethereum        ETH
# 3                    tether       USDT
# 4              binance-coin        BNB
# 5                   cardano        ADA
# 6                  dogecoin       DOGE
# 7                       xrp        XRP
# 8                  usd-coin       USDC
# 9              polkadot-new        DOT
# 10                  uniswap        UNI
# 11        internet-computer        ICP
# 12             bitcoin-cash        BCH
# 13                chainlink       LINK
# 14                 litecoin        LTC
# 15                   solana        SOL
# 16                  polygon      MATIC
# 17              binance-usd       BUSD
# 18                    theta      THETA
# 19                  stellar        XLM
# 20                  vechain        VET
# 21         ethereum-classic        ETC
# 22                 filecoin        FIL
# 23          wrapped-bitcoin       WBTC
# 24                      eos        EOS
# 25                     tron        TRX
# 26                   monero        XMR
# 27     multi-collateral-dai        DAI
# 28                     aave       AAVE
# 29                      neo        NEO
# 30                    maker        MKR
# ...                     ...        ...
# 5501             beer-token       BEER
# 5502         aurora-finance       AURO
# 5503        elongate-deluxe     ELONGD
# 5504              lady-luck       LUCK
# 5505       snowball-finance       SNOB
# 5506              avalaunch       XAVA
# 5507                velorex        VEX
# 5508                evai-io       EVAI
# 5509               xxxnifty       NSFW
# 5510            rafflection       RAFF
# 5511              wild-ride       WILD
# 5512                 azeusx        AZX
# 5513              poorocket  POOROCKET
# 5514                   chad       CHAD
# 5515             grill-farm      GRILL
# 5516              gingercat       GCAT
# 5517            dingo-token      DINGO
# 5518             wise-token       WISB
# 5519          panda-finance       PAND
# 5520         rocket-moon-go    SKYLARK
# 5521              seraphium       SRPH
# 5522               polydoge   POLYDOGE
# 5523  gold-secured-currency        GSX
# 5524            elk-finance        ELK
# 5525                petbloc       PETB
# 5526   museum-of-crypto-art       MOCA
# 5527               polywolf       MOON
# 5528                mimatic    MIMATIC
# 5529             spiritswap     SPIRIT
# 5530         wrapped-fantom       WFTM
#
# [5530 rows x 8 columns]

# %%
eth_data_quote = cmc.cryptocurrency_quotes_latest(symbol='ETH', convert='USD')
btc_data_quote = cmc.cryptocurrency_quotes_latest(symbol='BTC', convert='USD')
eth_data_quote_df = pd.DataFrame(eth_data_quote.data)
btc_data_quote_df = pd.DataFrame(btc_data_quote.data)
eth_df = eth_data_quote_df.T
eth_df
# Out:
#     circulating_supply cmc_rank                date_added    id is_active  \
# ETH        1.16169e+08        2  2015-08-07T00:00:00.000Z  1027         1
#
#     is_fiat              last_updated max_supply      name num_market_pairs  \
# ETH       0  2021-06-05T19:13:02.000Z       None  Ethereum             6048
#
#     platform                                              quote      slug  \
# ETH     None  {'USD': {'price': 2629.540101785351, 'volume_2...  ethereum
#
#     symbol                                               tags total_supply
# ETH    ETH  [mineable, pow, smart-contracts, ethereum, coi...  1.16169e+08

# %%
eth_price = eth_df['quote']
eth_price['USD']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4380             try:
# -> 4381                 return libindex.get_value_box(s, key)
#    4382             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-e6a3cddac2c4> in <module>
#       1 eth_price = eth_df['quote']
# ----> 2 eth_price['USD']
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4387                     raise InvalidIndexError(key)
#    4388                 else:
# -> 4389                     raise e1
#    4390             except Exception:  # pragma: no cover
#    4391                 raise e1
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'USD'

# %%
btc_dom= global_df['btc_dominance']
stablecoin_mktcap= global_df['stablecoin_market_cap']
deriv_pctchange= global_df['derivatives_24h_percentage_change']
total_market_cap =global_df['quote']['USD']['total_market_cap']
altcoin_mktcap = global_df['quote']['USD']['altcoin_market_cap']
last_updated = global_df['quote']['USD']['last_updated']
